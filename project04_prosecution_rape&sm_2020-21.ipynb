# %%
import pandas as pd
df = pd.read_csv('prosecution_yearly.csv')
df.head(20)
# Out:
#         統計名：  検察統計 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN   NaN        NaN                 NaN   /時間軸(年次)      2021年
# 1        NaN   NaN        NaN                 NaN  /既済事由 コード        110
# 2   表章項目 コード  表章項目  罪名_年次 コード               罪名_年次      /既済事由      起訴【人】
# 3        120    人員        100                  総数        NaN    244,425
# 4        120    人員        110                 刑法犯        NaN    100,890
# 5        120    人員        150          刑法犯_公務執行妨害        NaN        836
# 6        120    人員        190              刑法犯_放火        NaN        233
# 7        120    人員        260            刑法犯_住居侵入        NaN      2,074
# 8        120    人員        370   刑法犯_支払用カード電磁的記録関係        NaN         26
# 9        120    人員        420  刑法犯_わいせつ・わいせつ文書頒布等        NaN      1,291
# 10       120    人員        450          刑法犯_強制わいせつ        NaN      1,187
# 11       120    人員        464           刑法犯_強制性交等        NaN        455
# ...

# %%
new_df = df[df['Unnamed: 3'].isin(['刑法犯_強制わいせつ', '刑法犯_強制性交等'])]

# Display the resulting DataFrame
print(new_df)
# Out:
#    統計名： 検察統計 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 10  120   人員        450  刑法犯_強制わいせつ        NaN      1,187      2,563
# 11  120   人員        464   刑法犯_強制性交等        NaN        455        948
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 76 Unnamed: 77 Unnamed: 78  \
# 10       31.7      1,226      2,395  ...        50.8         587         649
# 11       32.4        502        853  ...        69.1         766         372
#
#    Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 10        47.5         565         613        48.0         558         600
# 11        67.3         732         366        66.7         767         385
#
#    Unnamed: 85
# 10        48.2
# 11        66.6
#
# [2 rows x 86 columns]

# %%
new_df
# Out:
#    統計名： 検察統計 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 10  120   人員        450  刑法犯_強制わいせつ        NaN      1,187      2,563
# 11  120   人員        464   刑法犯_強制性交等        NaN        455        948
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 76 Unnamed: 77 Unnamed: 78  \
# 10       31.7      1,226      2,395  ...        50.8         587         649
# 11       32.4        502        853  ...        69.1         766         372
#
#    Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 10        47.5         565         613        48.0         558         600
# 11        67.3         732         366        66.7         767         385
#
#    Unnamed: 85
# 10        48.2
# 11        66.6
#
# [2 rows x 86 columns]

# %%
year_df = new_df[['Unnamed: 5', 'Unnamed: 6']]
year_df
# Out:
#    Unnamed: 5 Unnamed: 6
# 10      1,187      2,563
# 11        455        948

# %%
year_df.rename(columns={'Unnamed: 5': '起訴', 'Unnamed: 6': '不起訴'})
# Out:
#        起訴    不起訴
# 10  1,187  2,563
# 11    455    948
